# %%
#Example courtesy: https://towardsdatascience.com/

# %%
#Importing

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
#Creating sample points

# %%
np.random.seed(0)
x = np.arange(-5,5,0.1)
y = -x**4 + np.random.normal(0,0.5,len(x))
plt.scatter(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
len(x)
# Out:
# 100

# %%
#Dividing data into training and testing sets

# %%
X_train = x[0:80]
y_train = y[0:80]
X_test = x[80:]
y_test = y[80:]

# %%
#Creatig function for polynomial curve fitting

# %%
def polynomial_fit(degree = 1):
  return np.poly1d(np.polyfit(X_train,y_train,degree))

# %%
#Another funtion to fit and display results

# %%
def plot_polyfit(degree = 1):
  p = polynomial_fit(degree)
  plt.scatter(X_train,y_train,label="Training set")
  plt.scatter(X_test,y_test,label="Test set")
  curve_x = np.arange(min(x),max(x),0.01)
  plt.plot(curve_x,p(curve_x),label="Polynomial of degree{}".format(degree))
  plt.xlim((-5,5))
  plt.ylim((-625,np.max(y)+0.1))
  
  plt.legend()
  plt.plot()

# %%
#Plotting the curve fitting on degree 1

# %%
plot_polyfit(1)

# %%
#Fitting and plotting resutls on degree 2
plot_polyfit(2)

# %%
#Fitting and plotting resutls on degree 3
plot_polyfit(3)

# %%
#Fitting and plotting resutls on degree 4
plot_polyfit(4)

# %%
#Fitting and plotting resutls on degree 6
plot_polyfit(6)

# %%
#Fitting and plotting resutls on degree 8
plot_polyfit(8)

# %%
#Fitting and plotting resutls on degree 10
plot_polyfit(10)

# %%
#Fitting and plotting resutls on degree 12
plot_polyfit(12)

# %%
#Fitting and plotting resutls on degree 15
plot_polyfit(15)

# %%
#Calculating root mean square error

# %%
results = []
for i in range(1,len(X_train)-65):
  p = polynomial_fit(i)
  rmse_training = np.sqrt(mean_squared_error(y_train,p(X_train)))
  rmse_test = np.sqrt(mean_squared_error(y_test,p(X_test)))
  results.append({'degree':i,
    'rmse_training':rmse_training,'rmse_test':rmse_test})
plt.plot([x['degree'] for x in results],[x['rmse_training'] for x in results],label="RMSE on training")
plt.plot([x['degree'] for x in results],[x['rmse_test'] for x in results],label="RMSE on test")
plt.yscale("log")
plt.xlabel("Polynomial degree")
plt.ylabel("RMSE")
plt.legend()
plt.show()
